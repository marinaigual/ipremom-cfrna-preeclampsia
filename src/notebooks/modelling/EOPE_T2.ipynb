# %% [markdown]
# # Model Optimization of EOPE T2 Classifier V6

# %% [markdown]
# ## Imports

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np

# %%
from src.utils.data_loader import get_train_validation_input
from src.utils.data_loader import load_configuration_yaml
from src.utils.data_loader import save_predictor

# %%
from src.utils.model_optimizer.optimizer import get_best_params_cv
from src.utils.model_optimizer.optimizer import get_f1_score_loo
from src.utils.model_optimizer.optimizer import get_f1_score_cfv
from src.utils.model_optimizer.optimizer import get_f1_score_oss
from src.utils.model_optimizer.optimizer import get_model_opotimal
from src.utils.model_optimizer.optimizer import get_f1_data
from src.utils.model_optimizer.optimizer import get_prediction_loo
from src.utils.model_optimizer.optimizer import get_metrics_splits_ic
from src.utils.model_optimizer.evaluator import calculate_metrics
from src.utils.model_optimizer.evaluator import print_confusion_matrix

# %%
from src.utils.modelling_plots.modelplots import model_evaluation_plots
from src.utils.modelling_plots.modelplots import auc_plot_test_val
from src.utils.modelling_plots.modelplots import auc_plot_loo_val

# %%
from sklearn.svm import SVC

from sklearn.linear_model import  Lasso
from sklearn.linear_model import ElasticNet
from sklearn.ensemble import RandomForestClassifier

from xgboost import XGBClassifier

from tabpfn import TabPFNClassifier

# %% [markdown]
# ### Globals

# %%
type_PE = "EOPE"
time = "T2"
DATASET_NAME = "eope_t2"
FOLDER_SAVE = "/Users/migual/Documents/iPremom/Data/cfRNA/cfRNA-v6/data-modelling-optimization/final_model_v6/"
PATH_INPUT = "/Users/migual/Documents/iPremom/Data/cfRNA/cfRNA-v6/data-modelling-optimization/EOPE_T2/"
path_cm = PATH_INPUT + "input_model_eope_ctr_t2_v6_87g_221024.csv"

# %%
CONFIG_PATH = "../../../config/model_optimizer/"

# %%
svm_config_file = CONFIG_PATH + "svc_config_parameters.yml"
lasso_config_file = CONFIG_PATH + "lasso_config_parameters.yml"
elasticnet_config_file = CONFIG_PATH + "elasticnet_config_parameters.yml"
xgb_config_file = CONFIG_PATH + "xgb_config_parameters.yml"
rf_config_file = CONFIG_PATH + "rf_config_parameters.yml"

# %% [markdown]
# ### Input Data Loading

# %%
# Loading dicovery and validation datasets
x_train, y_train, x_val, y_val = get_train_validation_input(
    path_file_input=path_cm,
)

# %%
# Exploration of Datasets
shape_discovery = x_train.shape
shape_validation = x_val.shape
print(f"Total number of samples  {shape_discovery[0]+shape_validation[0]}")
print(f"Number samples discovery {shape_discovery[0]}")
print(f"Number samples validation {shape_validation[0]}")
# Out:
# Total number of samples  113
# Number samples discovery 79
# Number samples validation 34

# %%
print(f"Number of CONTROL samples in training and validation datasets: {list(y_train).count(0)} | {list(y_val).count(0)}")
print(f"Number of {type_PE} samples in training and validation datasets: {list(y_train).count(1)} | {list(y_val).count(1)}")
print(f"Number of genes in training and validation datasets: {x_train.shape[1]} | {x_val.shape[1]}")
# Out:
# Number of CONTROL samples in training and validation datasets: 54 | 19
# Number of EOPE samples in training and validation datasets: 25 | 15
# Number of genes in training and validation datasets: 87 | 87

# %%
NUMBER_GENES = x_train.shape[1]

# %%
train_proportions = round(100*(list(y_train)).count(1)/len(y_train), 2)
val_proportions = round(100*(list(y_val)).count(1)/len(y_val), 2)

print(f"Proportion of {type_PE} in discovey dataset {train_proportions}%")
print(f"Proportion of {type_PE} in validation dataset {val_proportions}%")
# Out:
# Proportion of EOPE in discovey dataset 31.65%
# Proportion of EOPE in validation dataset 44.12%

# %% [markdown]
# ### Load Configuration Data

# %%
param_grid_svc = load_configuration_yaml(path_configuration_yaml=svm_config_file)
param_grid_lasso = load_configuration_yaml(path_configuration_yaml=lasso_config_file)
param_grid_elasticnet = load_configuration_yaml(path_configuration_yaml=elasticnet_config_file)
param_grid_xgb = load_configuration_yaml(path_configuration_yaml=xgb_config_file)
param_grid_rf = load_configuration_yaml(path_configuration_yaml=rf_config_file)

# %% [markdown]
# ### Algorithm Optimization with Cross Fold Validation

# %%
alg_parameter_search = {"SVC": [SVC(), param_grid_svc],
                        "Lasso": [Lasso(), param_grid_lasso],
                        "ElasticNet": [ElasticNet(), param_grid_elasticnet],
                        "RandomForest": [RandomForestClassifier(), param_grid_rf],
                        "XGBoost": [XGBClassifier(), param_grid_xgb]
}

alg_best_parameters = {
    "TabPFNClassifier": None,
    "SVC": {},
    "Lasso": {},
    "ElasticNet": {},
    "RandomForest": {},
    "XGBoost": {},
}

# %%
for alg_name, alg in alg_parameter_search.items():
    best_parameters = get_best_params_cv(clf_algorithm=alg[0],
                                         parameters_search=alg[1],
                                         x_train=x_train,
                                         y_train=y_train,
                                         )
    alg_best_parameters[alg_name] = best_parameters
# Out:
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.656e+00, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.973e+00, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.574e+00, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.143e+00, tolerance: 1.375e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.241e+00, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.084e+00, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.453e+00, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.241e+00, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.663e+00, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.344e+00, tolerance: 1.375e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.551e+00, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.212e+00, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.649e+00, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.092e+00, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.130e+00, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.564e+00, tolerance: 1.375e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.521e+00, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.117e+00, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.634e+00, tolerance: 1.375e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.384e+00, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.596e+00, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.818e-01, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.322e+00, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.805e-01, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.351e+00, tolerance: 1.375e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.514e-01, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.118e-01, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.337e+00, tolerance: 1.375e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.068e+00, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.163e+00, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.293e+00, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.301e+00, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.066e+00, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.996e-01, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.186e+00, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.205e+00, tolerance: 1.375e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.223e-01, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.223e+00, tolerance: 1.375e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.307e+00, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.048e+00, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.017e+00, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.153e+00, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.677e-01, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.064e+00, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.050e-01, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.224e+00, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.545e-01, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.121e+00, tolerance: 1.375e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.101e-01, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.008e+00, tolerance: 1.375e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.923e-01, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.744e-01, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.155e+00, tolerance: 1.375e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.461e-01, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.052e-01, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.420e-01, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.925e-01, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.205e-01, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.818e-01, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.610e-01, tolerance: 1.375e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.843e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.602e-01, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.578e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.157e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.552e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.810e-02, tolerance: 1.375e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.951e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.711e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.727e-01, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.918e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.590e-01, tolerance: 1.375e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.588e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.577e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.395e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.406e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.270e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.585e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.241e-02, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.317e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.715e-01, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.500e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.351e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.171e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.103e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.426e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.070e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.382e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.361e-02, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.102e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.876e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.906e-01, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.745e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.404e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.892e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.005e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.246e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.574e-01, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.610e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.205e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.711e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.911e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.902e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.085e-01, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.040e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.857e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.414e-01, tolerance: 1.375e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.283e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.858e-01, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.904e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.230e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.760e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.785e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.522e-02, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.694e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.742e+00, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.284e-02, tolerance: 1.365e-03
#   model = cd_fast.enet_coordinate_descent(
# ...
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.160e-02, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.085e-01, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.010e-02, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.937e-01, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.171e-02, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.509e-02, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.678e-02, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.043e-02, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.282e-02, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.710e-02, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.859e-02, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.775e-01, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.165e-02, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.714e-02, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.222e-01, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.108e-02, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.475e-01, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.503e-01, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.596e-01, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.188e-02, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.414e-01, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.370e-01, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.258e-03, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.538e-02, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.297e-03, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.143e-03, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.265e-02, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.812e-03, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.388e-02, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.159e-01, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.182e-01, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.287e-01, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.165e-01, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.163e-01, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.296e-03, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.601e-03, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.013e-01, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.031e-01, tolerance: 2.000e-03
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# ### Algorithm Evaluation with LOO, CFV and OSS

# %%
alg_metrics = {"TabPFNClassifier": TabPFNClassifier,
                "SVC": SVC,
                "Lasso": Lasso,
                "ElasticNet": ElasticNet,
                "RandomForest": RandomForestClassifier,
                "XGBoost": XGBClassifier
}

alg_probabilities = {
    "TabPFNClassifier": True,
    "SVC": True,
    "Lasso": False,
    "ElasticNet": False,
    "RandomForest": True,
    "XGBoost": True,
}

alg_f1_metrics = {
    "TabPFNClassifier": [0, 0, 0, 0],   # F1 LOO, CFV, OSS, VAL
    "SVC": [0, 0, 0, 0], # F1 LOO, CFV, OSS, VAL
    "Lasso": [0, 0, 0, 0],    # F1 LOO, CFV, OSS, VAL
    "ElasticNet": [0, 0, 0, 0],   # F1 LOO, CFV, OSS, VAL
    "RandomForest": [0, 0, 0, 0], # F1 LOO, CFV, OSS, VAL
    "XGBoost": [0, 0, 0, 0],  # F1 LOO, CFV, OSS, VAL
}

# %%
for alg_name, alg in alg_metrics.items():
    f1_loo = get_f1_score_loo(alg,
                              alg_best_parameters[alg_name],
                              x_train,
                              y_train,
                              alg_probabilities[alg_name])
    f1_cfv = get_f1_score_cfv(alg,
                              alg_best_parameters[alg_name],
                              x_train,
                              y_train,
                              alg_probabilities[alg_name])
    f1_oss = get_f1_score_oss(alg,
                              alg_best_parameters[alg_name],
                              x_train,
                              y_train,
                              alg_probabilities[alg_name])
    trained_clf, trained_thr = get_model_opotimal(alg,
                              alg_best_parameters[alg_name],
                              x_train,
                              y_train,
                              alg_probabilities[alg_name])
    f1_val = get_f1_data(trained_clf,
                         trained_thr,
                         x_val, y_val,
                         alg_probabilities[alg_name])
    alg_f1_metrics[alg_name] = [round(100*f1_loo),
                                round(100*f1_cfv),
                                round(100*f1_oss), 
                                round(100*f1_val)]
# Out:
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# ...
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.426e+00, tolerance: 2.400e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.324e+00, tolerance: 2.400e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.312e+00, tolerance: 2.400e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.380e+00, tolerance: 2.400e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.449e+00, tolerance: 2.400e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.470e+00, tolerance: 2.500e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.545e+00, tolerance: 2.400e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.554e+00, tolerance: 2.500e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.457e+00, tolerance: 2.500e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.645e+00, tolerance: 2.500e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.424e+00, tolerance: 2.500e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.358e+00, tolerance: 2.500e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.402e+00, tolerance: 2.500e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.422e+00, tolerance: 2.500e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.511e+00, tolerance: 2.500e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.417e+00, tolerance: 2.500e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.473e+00, tolerance: 2.500e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.405e+00, tolerance: 2.500e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.235e+00, tolerance: 2.400e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.528e+00, tolerance: 2.500e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.541e+00, tolerance: 2.400e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.375e+00, tolerance: 2.400e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.534e+00, tolerance: 2.500e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.479e+00, tolerance: 2.500e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.240e+00, tolerance: 2.400e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.466e+00, tolerance: 2.400e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.438e+00, tolerance: 2.500e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.277e+00, tolerance: 2.400e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.061e+00, tolerance: 2.400e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.543e+00, tolerance: 2.400e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.276e+00, tolerance: 2.400e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.615e+00, tolerance: 2.200e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.781e+00, tolerance: 2.100e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.303e+00, tolerance: 2.200e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.475e+00, tolerance: 1.900e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.654e+00, tolerance: 1.600e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.267e+00, tolerance: 1.900e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.502e+00, tolerance: 2.500e-03
#   model = cd_fast.enet_coordinate_descent(

# %%
# Result prints 
for alg_name, f1_metrics in alg_f1_metrics.items():
    print(f"{alg_name}: F1 LOO {f1_metrics[0]} | F1 CFV {f1_metrics[1]}  | F1 OSS {f1_metrics[2]} ")
# Out:
# TabPFNClassifier: F1 LOO 69 | F1 CFV 67  | F1 OSS 60
# SVC: F1 LOO 71 | F1 CFV 59  | F1 OSS 73
# Lasso: F1 LOO 60 | F1 CFV 52  | F1 OSS 83
# ElasticNet: F1 LOO 60 | F1 CFV 55  | F1 OSS 83
# RandomForest: F1 LOO 53 | F1 CFV 48  | F1 OSS 44
# XGBoost: F1 LOO 47 | F1 CFV 43  | F1 OSS 0

# %% [markdown]
# ### Visualization of Model Optimization

# %%
model_evaluation_plots(alg_f1_metrics, "EOPE T2")

# %% [markdown]
# ### Final Model training

# %%
chosen_alg = "SVC"

# %%
alg_best_parameters[chosen_alg] = {'C': 1,
                                    'class_weight': None,
                                    'degree': 3,
                                    'gamma': 'scale',
                                    'kernel': 'rbf',
                                    'probability': True,
                                    'random_state': 42}

# %%
y_pred_loo, test_scores_loo, trained_thr = get_prediction_loo(
    alg_metrics[chosen_alg],
    alg_best_parameters[chosen_alg],
    x_train,
    y_train,
    True)
test_metrics_loo = get_metrics_splits_ic(y_train, np.array(y_pred_loo), 5)

# %%
trained_clf, trained_thr = get_model_opotimal(clf_algorithm=alg_metrics[chosen_alg],
                                              params_algorithm=alg_best_parameters[chosen_alg],
                                              x_train=x_train,
                                              y_train=y_train,
                                              bool_probabilities=alg_probabilities[chosen_alg])

# %%
val_probs = trained_clf.predict_proba(x_val)[:,1]
val_metrics = calculate_metrics(np.array(y_val), val_probs, trained_thr)

# %%
print("#### LEAVE ONE OUT METRICS ####")
for metric, value in test_metrics_loo.items():
    print(f"\t{metric}: {value[0]} +/- {value[1]}")
# Out:
# #### LEAVE ONE OUT METRICS ####
# 	Accuracy: 79 +/- 8.22
# 	Recall: 81 +/- 26.71
# 	F1_Score: 65 +/- 21.04
# 	AUC: 79 +/- 14.28
# 	Specificity: 94 +/- 7.87
# 	Precision: 56 +/- 20.96
# 	PPV: 81 +/- 26.71
# 	NPV: 76 +/- 8.74
# 	FDR: 19 +/- 26.71

# %%
print("#### LEAVE ONE OUT CM ####")
print_confusion_matrix(y_train, test_scores_loo, trained_thr)
# Out:
# #### LEAVE ONE OUT CM ####
# TN: 36
# FP: 18
# FN: 6
# TP: 19

# %%
print("#### VALIDATION METRICS ####")
for metric, value in val_metrics.items():
    print(f"\t{metric}: {value}")

print("#### VALIDATION CM ####")
print_confusion_matrix(y_val, val_probs, trained_thr)
# Out:
# #### VALIDATION METRICS ####
# 	Accuracy: 85
# 	Recall: 87
# 	F1_Score: 84
# 	AUC: 85
# 	Specificity: 89
# 	Precision: 81
# 	PPV: 87
# 	NPV: 84
# 	FDR: 13
# #### VALIDATION CM ####
# TN: 16
# FP: 3
# FN: 2
# TP: 13

# %%
y_val_list = list(y_val)
y_disc = list(y_train)
print(f"TOTAL DISCOVERY {len(y_disc)}, CTR {y_disc.count(0)}, EOPE {y_disc.count(1)}")
print(f"TOTAL VAL {len(y_val_list)}, CTR {y_val_list.count(0)}, EOPE {y_val_list.count(1)}")
# Out:
# TOTAL DISCOVERY 79, CTR 54, EOPE 25
# TOTAL VAL 34, CTR 19, EOPE 15

# %% [markdown]
# ### AUC Final Model

# %%
auc_plot_loo_val(y_test=y_train,
                 y_test_scores=test_scores_loo,
                 y_val=y_val,
                 y_val_scores=val_probs,
                 dataset_name="EOPE T2",
                 auc_test=test_metrics_loo["AUC"][0],
                 auc_val=val_metrics["AUC"],
                 num_splits=2)

# %% [markdown]
# ### Saving trained model

# %%
save_predictor(trained_clf=trained_clf,
               trained_thr=trained_thr,
               path_folder_save=FOLDER_SAVE,
               num_variables=NUMBER_GENES,
               dataset_name=DATASET_NAME)
# Out:
# /Users/migual/Documents/iPremom/Repositories/tg-data-analysis-cfRNA/src/utils/data_loader.py:68: ResourceWarning: unclosed file <_io.BufferedWriter name='/Users/migual/Documents/iPremom/Data/cfRNA/cfRNA-v6/data-modelling-optimization/final_model_v6//eope_t2_87_SVC_optimal_102924.sav'>
#   pickle.dump(trained_clf, open(path_file_name, 'wb'))
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
